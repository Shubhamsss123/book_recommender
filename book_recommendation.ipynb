# %%
import pandas as pd 
import numpy as np

# %%
df_books=pd.read_csv('Books.csv')
df_user=pd.read_csv('Users.csv')
df_rating=pd.read_csv('Ratings.csv')
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_5396\1023404250.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_books=pd.read_csv('Books.csv')

# %%
df_books.shape,df_user.shape,df_rating.shape
# Out:
# ((271360, 8), (278858, 3), (1149780, 3))

# %%
df_books['Book-Title'].unique().shape
# Out:
# (242135,)

# %%
df_user['User-ID'].unique().shape
# Out:
# (278858,)

# %%
df_books.info(),df_rating.info(),df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
# ...

# %%
df_books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
df_user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
df_rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
df_books.head(3)
# Out:
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2          HarperPerennial  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
df_user.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
df_rating.head(3)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0

# %%
name_rating=df_rating.merge(df_books,on='ISBN')

# %%
df_num=name_rating.groupby('Book-Title').count()[['Book-Rating']]

# %%
df_num.columns=['num_of_books']

# %%
df_num
# Out:
#                                                     num_of_books
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...             4
#  Always Have Popsicles                                         1
#  Apple Magic (The Collector's series)                          1
#  Ask Lily (Young Women of Faith: Lily Series, B...             1
#  Beyond IBM: Leadership Marketing and Finance f...             1
# ...                                                          ...
# Ã?Â?lpiraten.                                                  2
# Ã?Â?rger mit Produkt X. Roman.                                 4
# Ã?Â?sterlich leben.                                            1
# Ã?Â?stlich der Berge.                                          3
# Ã?Â?thique en toc                                              2
#
# [241071 rows x 1 columns]

# %%
df_avg_rating=name_rating.groupby('Book-Title')[['Book-Rating']].mean()

# %%
df_avg_rating
# Out:
#                                                     Book-Rating
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...     2.250000
#  Always Have Popsicles                                 0.000000
#  Apple Magic (The Collector's series)                  0.000000
#  Ask Lily (Young Women of Faith: Lily Series, B...     8.000000
#  Beyond IBM: Leadership Marketing and Finance f...     0.000000
# ...                                                         ...
# Ã?Â?lpiraten.                                          0.000000
# Ã?Â?rger mit Produkt X. Roman.                         5.250000
# Ã?Â?sterlich leben.                                    7.000000
# Ã?Â?stlich der Berge.                                  2.666667
# Ã?Â?thique en toc                                      4.000000
#
# [241071 rows x 1 columns]

# %%
df_final=df_num.join(df_avg_rating)

# %%
df_final.reset_index(inplace=True)

# %%
df_final=df_final[df_final['num_of_books']>250]

# %%
df_final.sort_values('Book-Rating',ascending=False,inplace=True)
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_5396\1611249171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.sort_values('Book-Rating',ascending=False,inplace=True)

# %%
df_final
# Out:
#                                                Book-Title  num_of_books  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)           428
# 80422        Harry Potter and the Goblet of Fire (Book 4)           387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)           278
# 80426   Harry Potter and the Order of the Phoenix (Boo...           347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)           556
# ...                                                   ...           ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))           265
# 233635                                           Whispers           286
# 143377                                  Presumed Innocent           294
# 94382                                        Isle of Dogs           288
# 234951                                        Wild Animus          2502
#
#         Book-Rating
# 80434      5.852804
# 80422      5.824289
# 80441      5.737410
# ...

# %%
df_popular=df_final.merge(df_books,on='Book-Title').drop_duplicates('Book-Title')

# %%
df_popular
# Out:
#                                             Book-Title  num_of_books  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)           428
# 3         Harry Potter and the Goblet of Fire (Book 4)           387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)           278
# 9    Harry Potter and the Order of the Phoenix (Boo...           347
# 13    Harry Potter and the Chamber of Secrets (Book 2)           556
# ..                                                 ...           ...
# 716       Vinegar Hill (Oprah's Book Club (Paperback))           265
# 717                                           Whispers           286
# 727                                  Presumed Innocent           294
# 733                                       Isle of Dogs           288
# 739                                        Wild Animus          2502
#
#      Book-Rating        ISBN        Book-Author Year-Of-Publication  \
# 0       5.852804  0439136350      J. K. Rowling                1999
# ...

# %% [markdown]
# want to users who rates more than 200 movies (inteligent users) and books who have more than 50 ratings

# %%
raters_user=

# %%
x=df_rating.groupby('User-ID').count()['ISBN']>200
inteligent_users=x[x].index

# %%
df_filter=name_rating[name_rating['User-ID'].isin(inteligent_users)]

# %%
df_filter.shape
# Out:
# (487671, 10)

# %%
df_rating.groupby('User-ID').count()['ISBN']>250
# Out:
# User-ID
# 2         False
# 7         False
# 8         False
# 9         False
# 10        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: ISBN, Length: 105283, dtype: bool

# %%
name_rating.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L'],
#       dtype='object')

# %%
y=name_rating.groupby('Book-Title').count()['Book-Author']>50

# %%
popular_books=y[y].index

# %%
df_filter=df_filter[df_filter['Book-Title'].isin(popular_books)]

# %%
df_filter.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L'],
#       dtype='object')

# %%
table=df_filter.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
k=df_filter['Book-Rating']!=0
k[k].shape
# Out:
# (27745,)

# %%
table.isnull().count()
# Out:
# User-ID
# 254       2381
# 2276      2381
# 2766      2381
# 2977      2381
# 3363      2381
#           ...
# 275970    2381
# 277427    2381
# 277478    2381
# 277639    2381
# 278418    2381
# Length: 896, dtype: int64

# %%
table.iloc[:,1:2][2276].isnull().count()
# Out:
# 2381

# %%
table.shape
# Out:
# (2381, 896)

# %%
table.fillna(0,inplace=True)

# %%
table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos=cosine_similarity(table)

# %%
set([i if 'Har' in i else 0 for i in table.index])
# Out:
# {0,
#  'Angels Flight (Detective Harry Bosch Mysteries)',
#  'Bitter Harvest',
#  'Blindness (Harvest Book)',
#  'Chesapeake Blue (Quinn Brothers (Hardcover))',
#  'Confessions of a Sociopathic Social Climber : The Katya Livingston Chronicles (Katya Livingston Chronicles (Hardcover))',
#  "Daughter of Fortune : A Novel (Oprah's Book Club (Hardcover))",
#  'Good Harbor: A Novel',
#  'Grave Secrets (Temperance Brennan Novel (Hardcover))',
#  'Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#  'Hard Time (V.I. Warshawski Novels (Paperback))',
#  'Harmful Intent',
#  'Harriet the Spy',
#  'Harry Potter and the Chamber of Secrets (Book 2)',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  'Harry Potter and the Order of the Phoenix (Book 5)',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#  'Harvest',
# ...

# %%
np.where(table.index=='10 Lb. Penalty')[0][0]
# Out:
# 0

# %%
arr=np.array([1,2,3])

# %%
np.where(arr==3)
# Out:
# (array([2], dtype=int64),)

# %%
def book_data(title):
    arr=df_books[df_books['Book-Title']=='Harry Potter and the Chamber of Secrets (Book 2)'].iloc[:1,:].values
#     print(arr)
#     return arr
    arr=arr[0]
    return [arr[2],arr[3],arr[7]]

# %%
df_books[df_books['Book-Title']=='Harry Potter and the Chamber of Secrets (Book 2)'].iloc[:1,:]
# Out:
#             ISBN                                        Book-Title  \
# 3459  0439064872  Harry Potter and the Chamber of Secrets (Book 2)
#
#         Book-Author Year-Of-Publication   Publisher  \
# 3459  J. K. Rowling                2000  Scholastic
#
#                                             Image-URL-S  \
# 3459  http://images.amazon.com/images/P/0439064872.0...
#
#                                             Image-URL-M  \
# 3459  http://images.amazon.com/images/P/0439064872.0...
#
#                                             Image-URL-L
# 3459  http://images.amazon.com/images/P/0439064872.0...

# %%
def find_similar(book):
    
    index=np.where(table.index==book)[0][0]
    
    s=[i[0] for i in sorted(list(enumerate(cos[index])),key=lambda x:x[1],reverse=True)[1:4]]
    
    return [book_data(table.index[x]) for x in s]

# %%
find_similar('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [['J. K. Rowling',
#   2000,
#   'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'],
#  ['J. K. Rowling',
#   2000,
#   'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'],
#  ['J. K. Rowling',
#   2000,
#   'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg']]

# %%
sorted(list(enumerate(cos[0])),key=lambda x:x[1],reverse=True)
# Out:
# [(0, 1.0),
#  (490, 0.4634897582061269),
#  (686, 0.43694983928441683),
#  (504, 0.37358786588264326),
#  (965, 0.3662505400886533),
#  (2012, 0.3635642423874725),
#  (1620, 0.34490732452138384),
#  (2111, 0.3288382658013679),
#  (1181, 0.32658038167850056),
#  (1230, 0.31783424022533796),
#  (1375, 0.28260240634765676),
#  (1404, 0.2821910392572488),
#  (1149, 0.26977154919387747),
#  (2168, 0.2544919108926068),
#  (20, 0.25437541957532156),
#  (951, 0.2522731073332218),
#  (1817, 0.2522731073332218),
#  (403, 0.25171993131009057),
#  (2353, 0.24257231046246674),
#  (1358, 0.2414288129555069),
#  (2221, 0.2411475835610753),
#  (1065, 0.23784536654176383),
#  (1636, 0.237141600400228),
#  (272, 0.237040472976089),
#  (221, 0.22685916827039443),
#  (1487, 0.2246625242636544),
#  (1071, 0.21976640824893562),
#  (1717, 0.21971213823742808),
#  (106, 0.21922946992470282),
#  (753, 0.21517948312605892),
#  (930, 0.214832544072678),
#  (2252, 0.21029331637715773),
# ...

# %%
a=[1,3,2]

# %%
sorted(a,k)
# Out:
# [1, 2, 3]

# %%
popular_books
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='Book-Title', length=2381)

# %%
df_popular=df_books[df_books['Book-Title'].isin(popular_books)]

# %%
df_popular.drop_duplicates()
# Out:
#               ISBN                                         Book-Title  \
# 5       0399135782                             The Kitchen God's Wife
# 14      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 18      0440234743                                      The Testament
# 19      0452264464               Beloved (Plume Contemporary Fiction)
# 26      0971880107                                        Wild Animus
# ...            ...                                                ...
# 270710  0523416873                                       The Presence
# 270954  0399150684                                         Naked Prey
# 271055  087004124X                                             Anthem
# 271169  0395647398     The Two Towers (The Lord of the Rings, Part 2)
# 271315  1902852036                                All the Queen's Men
#
#              Book-Author Year-Of-Publication              Publisher  \
# ...

# %%
df_50=df_popular.iloc[:,:51]

# %%
df_50['rating']=df_50['Book-Rating'].apply(lambda x: round(x,2))

# %%
df_50=df_50[['Book-Title','Book-Author','Image-URL-L','rating','Year-Of-Publication']]

# %%
df_50.columns=['title','author','url','rating','year']

# %%
df_50.columns
# Out:
# Index(['title', 'author', 'url', 'rating', 'year'], dtype='object')

# %%
import pickle

# %%
with open('cos_data.pkl','wb') as f:
    pickle.dump(cos,f)

# %%
with open('top.pkl','rb') as c:
    var=pickle.load(c)

# %%
var['title'].values
# Out:
# array(['Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        "Harry Potter and the Sorcerer's Stone (Book 1)",
#        'Harry Potter and the Order of the Phoenix (Book 5)',
#        'Harry Potter and the Chamber of Secrets (Book 2)',
#        'The Hobbit : The Enchanting Prelude to The Lord of the Rings',
#        'The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#        "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#        'The Two Towers (The Lord of the Rings, Part 2)',
#        'To Kill a Mockingbird', 'The Da Vinci Code',
#        'The Five People You Meet in Heaven', 'The Catcher in the Rye',
#        'The Lovely Bones: A Novel', '1984', 'Prodigal Summer: A Novel',
#        'Neverwhere', 'The Secret Life of Bees',
#        'Stupid White Men ...and Other Sorry Excuses for the State of the Nation!',
# ...

# %%
pd.__version__
# Out:
# '1.5.2'

# %%
df_c=pd.read_csv('tmdb_5000_credits.csv')

# %%
df_m=pd.read_csv('tmdb_5000_movies.csv')

# %%
df_m.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
df_c.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
import ast

# %%
ast.literal_eval(df_c['crew'].values[0])
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...
